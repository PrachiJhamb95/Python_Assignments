# %%
import pandas as pd
import re
import datetime as dt
pd.set_option('display.max_colwidth', None)

# %%
#read the TS in Harry Potter 1.csv (note, this is a semicolon separated dataset)
#this dataset was retrieved from https://www.kaggle.com/datasets/gulsahdemiryurek/harry-potter-dataset
df = pd.read_csv("data/Harry Potter 1.csv", sep = ";")
display(df)
# Out:
#        Character  \
# 0     Dumbledore
# 1     McGonagall
# 2     McGonagall
# 3     Dumbledore
# 4     Dumbledore
# ...          ...
# 1582      Hagrid
# 1583       Harry
# 1584      Hagrid
# 1585    Hermione
# 1586       Harry
#
#                                                                                                                                                                          Sentence
# 0                                                                                                                 I should've known that you would be here, Professor McGonagall.
# 1                                                                                                                                             Good evening, Professor Dumbledore.
# 2                                                                                                                                                     Are the rumors true, Albus?
# 3                                                                                                                                                       I'm afraid so, professor.
# 4                                                                                                                                                           The good and the bad.
# ...                                                                                                                                                                           ...
# 1582  Oh, listen, Harry, if that dolt of a cousin of yours, Dudley, gives you any grief, you could always, um, threaten him with a nice pair of ears to go with that tail of his.
# 1583                                                                                                 But Hagrid, we're not allowed to do magic away from Hogwarts. You know that.
# 1584                                                                                                                          I do. But your cousin don't, do he? Eh? Off you go.
# 1585                                                                                                                                  Feels strange to be going home, doesn't it?
# 1586                                                                                                                                              I'm not going home. Not really.
#
# [1587 rows x 2 columns]

# %%
#get all sentences that end in a question mark spoken by Ron (hint, use the str.contains method of a series)
df_Ron = df[df["Character"]== "Ron"]
df_Ron[df_Ron["Sentence"].str.contains(r"\.*.*\?$")]
# Out:
#      Character  \
# 383        Ron
# 390        Ron
# 392        Ron
# 412        Ron
# 414        Ron
# 417        Ron
# 497        Ron
# 565        Ron
# 710        Ron
# 722        Ron
# 859        Ron
# 1049       Ron
# 1051       Ron
# 1082       Ron
# 1434       Ron
# 1548       Ron
#
#                                                                 Sentence
# 383                                              Excuse me. Do you mind?
# 390                                   I mean, do you really have the...?
# 392                                                            The scar?
# 412          Well, you can't expect him to hang around all day, can you?
# 414                                                  Pathetic, isn't he?
# 417                                                         Want to see?
# 497                                                   Harry, what is it?
# 565   Can you imagine the look on old McGonagall's face if we were late?
# 710                       Does anybody feel like...we shouldn't be here?
# 722                                                           Alohomora?
# 859                                                What are friends for?
# 1049                                                   Wanna play chess?
# 1051                                          Wanna go and visit Hagrid?
# 1082                                                   Leg-Locker Curse?
# 1434           Do you want to stop Snape from getting that Stone or not?
# 1548                                                     All right? You?

# %%
#get all of the sentences that mention both Harry and Ron
df_Ron_Harry = df[df["Sentence"].str.contains(r"(?=.*Harry)(?=.*Ron)")]
df_Ron_Harry
# Out:
#       Character                                      Sentence
# 845  Hermione    If Harry and Ron hadn't come and found me...
# 861    Hermione                          Ron's right, Harry.

# %%
#get all of the sentences that start with a number
df_num = df[df["Sentence"].str.contains(r"(^[0-9])")]
df_num
# Out:
# C:\Users\kjjoh\AppData\Local\Temp\ipykernel_35364\3203297458.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_num = df[df["Sentence"].str.contains(r"(^[0-9])")]
#          Character  \
# 42          Vernon
# 43          Dudley
# 364    Trainmaster
# 849   McGonagall
# 852   McGonagall
# 900     Lee Jordan
# 1009         Harry
# 1174       Harry
#
#                                                                         Sentence
# 42                                                      36. Counted them myself.
# 43                                     36?! But last year... last year I had 37!
# 364                                      9 3/4? Think you're being funny, do ya?
# 849   5 points will be taken from Gryffindor for your serious lack of judgment.
# 852                                  5 points...will be awarded to each of you.
# 900                                                   10 points for Gryffindor!
# 1009                                             15th Century Fiends...Flamel...
# 1174                                                                        50?!

# %%
#get all sentences that mention a professor at the end of a sentence excluding punctuation, and extract just name of the professor mentioned (hint, concatenate the result of the extract operation with the original dataframe along axis=1) and then dropna() to eliminate the ones that had no mention
df_prof = df[df["Sentence"].str.contains(r"(?<=Professor ).\w+\.|(?<=Professor ).\w+\?")] 
df_prof1 = df_prof.Sentence.str.extract(r"((?<=Professor ).\w+)",flags=re.IGNORECASE)  
df_Professor = pd.concat([df_prof1,df_prof],axis=1) 
df_Professor.rename(columns={0:"Mentioned"},inplace=True) 
display(df_Professor)
# Out:
#        Mentioned   Character  \
# 0     McGonagall  Dumbledore
# 1     Dumbledore  McGonagall
# 10    McGonagall      Hagrid
# 231     Quirrell      Hagrid
# 523     Quirrell       Harry
# 840   McGonagall  Hermione
# 1455    Quirrell   Quirrell
#
#                                                                          Sentence
# 0                 I should've known that you would be here, Professor McGonagall.
# 1                                             Good evening, Professor Dumbledore.
# 10                                                          Professor McGonagall.
# 231                                           Harry, This is Professor Quirrell.
# 523                 Say, Percy, who's that teacher talking to Professor Quirrell?
# 840                                         It's my fault, Professor McGonagall.
# 1455  Next to him, who would suspect, "p-p-poor s-stuttering Professor Quirrell?"

# %%
#extract quotes contained within any sentence
df_quote = df[df["Sentence"].str.contains(r'"([^"]*)"')]
df_quoted = df_quote.Sentence.str.extract(r'"([^"]*)"',flags=re.IGNORECASE)
df_concat = pd.concat([df_quoted,df_quote],axis=1)
df_concat.rename(columns={0:"Quoted"},inplace=True)
display(df_concat)
# Out:
# C:\Users\kjjoh\AppData\Local\Temp\ipykernel_35364\3392501821.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_quote = df[df["Sentence"].str.contains(r'"([^"]*)"')]
#                                              Quoted    Character  \
# 625                                             Up.  Madam Hooch
# 1007                                   Use it well.        Harry
# 1178                                the four of us.       Malfoy
# 1286  After Fluffy, a dragon's gonna be no problem.     Hagrid
# 1455      p-p-poor s-stuttering Professor Quirrell?    Quirrell
#
#                                                                          Sentence
# 625                           Stick your right hand over the broom and say, "Up."
# 1007                                                 It just said, "Use it well."
# 1178                                       I thought you said..."the four of us."
# 1286          I told him. I said, "After Fluffy, a dragon's gonna be no problem."
# 1455  Next to him, who would suspect, "p-p-poor s-stuttering Professor Quirrell?"

# %%
#extract the first hyphenated word in each sentence, where the first word is at least 2 characters
df_hyphenated = df.loc[df.Sentence.str.contains(r"(?=\S{2,}[-])([a-zA-Z-]+)"),:]
df_hyph = df_hyphenated.Sentence.str.extract(r"(?=\S{2,}[-])([a-zA-Z-]+)",flags=re.IGNORECASE)
df_output = pd.concat([df_hyph,df_hyphenated],axis=1)
df_output.rename(columns={0:"Hyphenated"},inplace=True)
display(df_output)
# Out:
# C:\Users\kjjoh\AppData\Local\Temp\ipykernel_35364\3026020448.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_hyphenated = df.loc[df.Sentence.str.contains(r"(?=\S{2,}[-])([a-zA-Z-]+)"),:]
#                     Hyphenated     Character  \
# 195                  Non-magic        Hagrid
# 246                world-class           Boy
# 266              You-Know-What        Hagrid
# 306   He-Who-Must-Not-Be-Named    Ollivander
# 338               You-Know-Who         Harry
# 400            bogey-flavoured           Ron
# 457              rule-breaking    McGonagall
# 469               hand-me-down        Malfoy
# 482              start-of-term    Dumbledore
# 484                third-floor    Dumbledore
# 568               pocket-watch    McGonagall
# 573                wand-waving         Snape
# 574              potion-making         Snape
# 755                     beater      Oliver
# 778                 Levio-saaa       Draco
# 931                   Whoo-hoo    Hermione
# 1017                   Severus    Quirrell
# 1082                Leg-Locker           Ron
# 1205              Nighty-night        Filch
# 1235                 half-life      Firenze
# 1249              You-Know-Who      Hermione
# 1302            well-protected  McGonagall
# 1349               plant-thing         Ron
# 1455                  p-p-poor     Quirrell
# 1459             counter-curse    Quirrell
# 1463                   Th-then        Harry
# 1578                  good-bye        Hagrid
#
#                                                                                                                                                                                          Sentence
# 195                                                                                                                                                                               Non-magic folk.
# 246                                                                                                                                                              It's a world-class racing broom.
# 266                                                                                                                                             It's about You-Know-What in vault you-know-which.
# 306                                                                                                                                         After all, He-Who-Must-Not-Be-Named did great things.
# 338                                                                                                                                                                              To You-Know-Who?
# 400                                                                                                                                             George sweared he got a bogey-flavoured one once!
# 457                                                                                                                                                  Any rule-breaking, and you will lose points.
# 469                                                                                                                                                             Red hair and a hand-me-down robe?
# 482                                                                                                                                        I have a few start-of-term notices I wish to announce.
# 484   Also, our caretaker, Mr. Filch, has asked me to remind you that the third-floor corridor on the right hand side is out of bounds to everyone who does not wish to die a most painful death.
# 568                                                                                            Perhaps, lt'd be more useful if I were to transfigure Mr. Potter and yourself into a pocket-watch.
# 573                                                                                                                     There will be no foolish wand-waving or silly incantations in this class.
# 574                                                                                     As such, I don't expect many of you to appreciate the subtle science and exact art that is potion-making.
# 755                                                                                                                                       Eh, not bad, Potter, you'd make a fair beater...Uh-oh.
# 778                                                                                                                                                                        Wingardium Levio-saaa.
# 931                                                                                                                                                                                     Whoo-hoo!
# 1017                                                                                                                                                                     Severus...I-I thought...
# 1082                                                                                                                                                                            Leg-Locker Curse?
# 1205                                                                                                                                                                                Nighty-night.
# 1235                                                                                    You have slain something so pure that the moment the blood touches your lips, you will have a half-life.
# 1249                                                                                                                                You mean, You-Know-Who's out there, right now, in the forest?
# 1302                                                                                  I don't know how you three found out about the stone, but I can assure you it is perfectly well-protected.
# 1349                                                                                                                                                      Lucky this plant-thing is here, really.
# 1455                                                                                                                  Next to him, who would suspect, "p-p-poor s-stuttering Professor Quirrell?"
# 1459                                                                                                                                          Even with Snape muttering his little counter-curse.
# 1463                                                                                                                                                                Th-then you let the troll in.
# 1578                                                                                                                                    Thought you were leaving without saying good-bye, didja?

# %%
# -5, no attempt
#extract a list of long words (>= 10 characters) from all sentences (findall is probably the easiest thing to use) that have at least two long words.  This is easier to do as a regex followed by a subset
#n = 10
#long_words = re.findall('^[A-Za-z\'\-]{'+str(n)+',}', df, re.M)
#print(long_words)

# %%
# -5, no attempt
#extract sentences where the speaker mentions themselves

# %%
# -5, no attempt
#display sentences where any word is repeated 4 or more times (note you may get a warning)
